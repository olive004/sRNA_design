# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Analyse RBS Calculator results for GFPmut3 and cyRFP1

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys


sns.set_style('whitegrid')

module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

__package__ = os.path.basename(module_path)

# %%
top_dir = os.path.join('data', '26_analyse_RBS_calc_mRNA')
fn_cyrfp = os.path.join('data', 'RBS_Calculator', 'RBS_Calc_08_11_2025_14_38_08-cyRFP1_Original.csv')
fn_gfp = os.path.join('data', 'RBS_Calculator', 'RBS_Calculator/RBS_Calc_09_10_2025_08_49_05-GFPmut3.csv')
df_cyrfp = pd.read_csv(fn_cyrfp)
df_gfp = pd.read_csv(fn_gfp)
